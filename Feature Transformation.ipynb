# %%
import pandas as pd
import numpy as np # mathematical library
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Super Shop.csv')

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df2 = df.drop(['Area'], axis = 1)# for col axis is 1 and for row axis is 0

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06
# 2        153441.51       101145.55  407934.54  191050.39
# 3        144372.41       118671.85  383199.62  182901.99
# 4        142107.34        91391.77  366168.42  166187.94

# %%
df3 = df2.copy()
df4 = df2.copy()
df5 = df2.copy()
df6 = df2.copy()
df7 = df2.copy()
df8 = df2.copy()
df9 = df2.copy()
df10 = df2.copy()
df11 = df2.copy()

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
m= MinMaxScaler()

# %%
df_ms = m.fit_transform(df2[['Marketing Spend']])

# %%
df_ms
# Out:
# array([[0.69261666],
#        [0.98335946],
#        [0.92798459],
#        [0.87313643],
#        [0.85943772],
#        [0.797566  ],
#        [0.81412828],
#        [0.7880179 ],
#        [0.72901786],
#        [0.74590551],
#        [0.61635061],
#        [0.60884455],
#        [0.56766982],
#        [0.55635219],
#        [0.72539353],
#        [1.        ],
#        [0.47180821],
#        [0.57246821],
#        [0.55488118],
#        [0.52264964],
#        [0.46116861],
#        [0.47408436],
#        [0.4475048 ],
#        [0.40842369],
#        [0.46594728],
#        [0.39107967],
#        [0.45557444],
#        [0.43609283],
#        [0.39946683],
#        [0.39676926],
#        [0.37493063],
#        [0.36974101],
#        [0.38348453],
#        [0.33561668],
#        [0.2807759 ],
#        [0.2782839 ],
#        [0.17335288],
#        [0.26652654],
#        [0.12234465],
#        [0.23319442],
#        [0.17390063],
#        [0.16869099],
#        [0.14297577],
# ...

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06
# 2        153441.51       101145.55  407934.54  191050.39
# 3        144372.41       118671.85  383199.62  182901.99
# 4        142107.34        91391.77  366168.42  166187.94

# %%
df2[['Marketing Spend']] = m.fit_transform(df2[['Marketing Spend']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0         0.692617       136897.80  471784.10  192261.83
# 1         0.983359       151377.59  443898.53  191792.06
# 2         0.927985       101145.55  407934.54  191050.39
# 3         0.873136       118671.85  383199.62  182901.99
# 4         0.859438        91391.77  366168.42  166187.94

# %%
df2[['Administration']] = m.fit_transform(df2[['Administration']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0         0.692617        0.651744  471784.10  192261.83
# 1         0.983359        0.761972  443898.53  191792.06
# 2         0.927985        0.379579  407934.54  191050.39
# 3         0.873136        0.512998  383199.62  182901.99
# 4         0.859438        0.305328  366168.42  166187.94

# %%
df2[['Transport']] = m.fit_transform(df2[['Transport']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0         0.692617        0.651744   1.000000  192261.83
# 1         0.983359        0.761972   0.940893  191792.06
# 2         0.927985        0.379579   0.864664  191050.39
# 3         0.873136        0.512998   0.812235  182901.99
# 4         0.859438        0.305328   0.776136  166187.94

# %% [markdown]
# # Normalization using Loop

# %%
df3.columns
# Out:
# Index(['Marketing Spend', 'Administration', 'Transport', 'Profit'], dtype='object')

# %%
x = df3.iloc[:,0:3]
y = df3.iloc[:,3:4]

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport
# 0        114523.61       136897.80  471784.10
# 1        162597.70       151377.59  443898.53
# 2        153441.51       101145.55  407934.54
# 3        144372.41       118671.85  383199.62
# 4        142107.34        91391.77  366168.42

# %%
y.head()
# Out:
#       Profit
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm= MinMaxScaler()

# %%
df3[['Administration']] = mm.fit_transform(df3[['Administration']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61        0.651744  471784.10  192261.83
# 1        162597.70        0.761972  443898.53  191792.06
# 2        153441.51        0.379579  407934.54  191050.39
# 3        144372.41        0.512998  383199.62  182901.99
# 4        142107.34        0.305328  366168.42  166187.94

# %%
df3[['Marketing Spend']] = mm.fit_transform(df3[['Marketing Spend']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0         0.692617        0.651744  471784.10  192261.83
# 1         0.983359        0.761972  443898.53  191792.06
# 2         0.927985        0.379579  407934.54  191050.39
# 3         0.873136        0.512998  383199.62  182901.99
# 4         0.859438        0.305328  366168.42  166187.94

# %%
df3[['Transport']] = mm.fit_transform(df3[['Transport']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0         0.692617        0.651744   1.000000  192261.83
# 1         0.983359        0.761972   0.940893  191792.06
# 2         0.927985        0.379579   0.864664  191050.39
# 3         0.873136        0.512998   0.812235  182901.99
# 4         0.859438        0.305328   0.776136  166187.94

# %%
x.columns
# Out:
# Index(['Marketing Spend', 'Administration', 'Transport'], dtype='object')

# %%
import warnings as wr
wr.filterwarnings('ignore')

# %%
for col in x.columns:
    if x[col].dtype == 'object':
        continue
    x[col] = mm.fit_transform(x[[col]])
x.head()
# Out:
#    Marketing Spend  Administration  Transport
# 0         0.692617        0.651744   1.000000
# 1         0.983359        0.761972   0.940893
# 2         0.927985        0.379579   0.864664
# 3         0.873136        0.512998   0.812235
# 4         0.859438        0.305328   0.776136

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06
# 2        153441.51       101145.55  407934.54  191050.39
# 3        144372.41       118671.85  383199.62  182901.99
# 4        142107.34        91391.77  366168.42  166187.94

# %%
df5[['Transport']] = ss.fit_transform(df5[['Transport']])

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80   2.165287  192261.83
# 1        162597.70       151377.59   1.929843  191792.06
# 2        153441.51       101145.55   1.626191  191050.39
# 3        144372.41       118671.85   1.417348  182901.99
# 4        142107.34        91391.77   1.273550  166187.94

# %%
df5[['Marketing Spend', 'Administration','Transport']] = ss.fit_transform(df5[['Marketing Spend', 'Administration','Transport']])

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0         0.897913        0.560753   2.165287  192261.83
# 1         1.955860        1.082807   1.929843  191792.06
# 2         1.754364       -0.728257   1.626191  191050.39
# 3         1.554784       -0.096365   1.417348  182901.99
# 4         1.504937       -1.079919   1.273550  166187.94

# %% [markdown]
# # Standardization using loop

# %%
p = df.iloc[:,0:4]
q = df.iloc[:,4:5]

# %%
p.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
q.head()
# Out:
#       Profit
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
p.columns
# Out:
# Index(['Marketing Spend', 'Administration', 'Transport', 'Area'], dtype='object')

# %%
for col in p.columns:
    if p[col].dtype == 'object':
        continue
    p[col] = ss.fit_transform(p[[col]])
p.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.897913        0.560753   2.165287    Dhaka
# 1         1.955860        1.082807   1.929843      Ctg
# 2         1.754364       -0.728257   1.626191  Rangpur
# 3         1.554784       -0.096365   1.417348    Dhaka
# 4         1.504937       -1.079919   1.273550  Rangpur

# %%
df34=df.copy()

# %%
for col in df34.columns:
    if df34[col].dtype == 'object':
        continue
    df34[col] = ss.fit_transform(df34[[col]])
df34.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.897913        0.560753   2.165287    Dhaka  2.011203
# 1         1.955860        1.082807   1.929843      Ctg  1.999430
# 2         1.754364       -0.728257   1.626191  Rangpur  1.980842
# 3         1.554784       -0.096365   1.417348    Dhaka  1.776627
# 4         1.504937       -1.079919   1.273550  Rangpur  1.357740

# %% [markdown]
# # LogTransformation

# %%
from sklearn.preprocessing import FunctionTransformer

# %%
funtra = FunctionTransformer(np.log1p)

# %%
df45=df.copy()

# %%
df45.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df45[['Marketing Spend', 'Administration','Transport']] = funtra.fit_transform(df45[['Marketing Spend', 'Administration','Transport']])

# %%
df45.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        11.648545       11.826997  13.064279    Dhaka  192261.83
# 1        11.999040       11.927539  13.003354      Ctg  191792.06
# 2        11.941081       11.524326  12.918864  Rangpur  191050.39
# 3        11.880158       11.684126  12.856314    Dhaka  182901.99
# 4        11.864345       11.422922  12.810851  Rangpur  166187.94

# %%
x1= df.iloc[:,0:4]
y1 = df.iloc[:,4:5]

# %%
x1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
y1.head()
# Out:
#       Profit
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %% [markdown]
# # LogTransformation using Loop

# %%
for col in x1.columns:
    if x1[col].dtype == 'object':
        continue
    x1[col] = ss.fit_transform(x1[[col]])
x1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.897913        0.560753   2.165287    Dhaka
# 1         1.955860        1.082807   1.929843      Ctg
# 2         1.754364       -0.728257   1.626191  Rangpur
# 3         1.554784       -0.096365   1.417348    Dhaka
# 4         1.504937       -1.079919   1.273550  Rangpur

# %%
df44= df.copy()

# %%
for col in df44.columns:
    if df44[col].dtype == 'object':
        continue
    df44[col] = funtra.fit_transform(df44[[col]])
df44.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        11.648545       11.826997  13.064279    Dhaka  12.166619
# 1        11.999040       11.927539  13.003354      Ctg  12.164172
# 2        11.941081       11.524326  12.918864  Rangpur  12.160298
# 3        11.880158       11.684126  12.856314    Dhaka  12.116711
# 4        11.864345       11.422922  12.810851  Rangpur  12.020881

# %% [markdown]
# # Max Absolute Scaler

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
mas = MaxAbsScaler()

# %%
df55= df.copy()

# %%
df55.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
x2 = df55.iloc[:,0:4]
y2 = df55.iloc[:,4:5]

# %%
x2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
y2.head()
# Out:
#       Profit
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %% [markdown]
# # Max Absolute Scaler Using Loop

# %%
for col in x2.columns:
    if x2[col].dtype == 'object':
        continue
    x2[col] = mas.fit_transform(x2[[col]])
x2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.692617        0.749527   1.000000    Dhaka
# 1         0.983359        0.828805   0.940893      Ctg
# 2         0.927985        0.553781   0.864664  Rangpur
# 3         0.873136        0.649738   0.812235    Dhaka
# 4         0.859438        0.500378   0.776136  Rangpur

# %%
df55[['Marketing Spend', 'Administration','Transport']] = mas.fit_transform(df55[['Marketing Spend', 'Administration','Transport']])

# %%
df55.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.759255        0.806965   1.000000    Dhaka  12.166619
# 1         0.987946        0.870901   0.956721      Ctg  12.164172
# 2         0.947094        0.635783   0.898915  Rangpur  12.160298
# 3         0.905456        0.722237   0.857770    Dhaka  12.116711
# 4         0.894866        0.585326   0.828742  Rangpur  12.020881

# %%
for col in df55.columns:
    if df55[col].dtype == 'object':
        continue
    df55[col] = funtra.fit_transform(df55[[col]])
df55.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.564891        0.591649   0.693147    Dhaka  2.577685
# 1         0.687102        0.626420   0.671270      Ctg  2.577499
# 2         0.666338        0.492121   0.641283  Rangpur  2.577205
# 3         0.644721        0.543624   0.619377    Dhaka  2.573887
# 4         0.639148        0.460790   0.603628  Rangpur  2.566554

# %% [markdown]
# # Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler

# %%
rb = RobustScaler()

# %%
df66 = df.copy()

# %%
df66.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
x3= df66.iloc[:,0:4]
y3= df66.iloc[:,4:5]

# %%
x3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
y3.head()
# Out:
#       Profit
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %% [markdown]
# # Robust Scaler using Loop

# %%
for col in x3.columns:
    if x3[col].dtype == 'object':
        continue
    x3[col] = rb.fit_transform(x3[[col]])
x3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.672530        0.345355   1.552016    Dhaka
# 1         1.452113        0.697565   1.383714      Ctg
# 2         1.303634       -0.524290   1.166654  Rangpur
# 3         1.156567       -0.097977   1.017368    Dhaka
# 4         1.119836       -0.761543   0.914576  Rangpur

# %%
df66[['Marketing Spend', 'Administration','Transport']] = mas.fit_transform(df66[['Marketing Spend', 'Administration','Transport']])

# %%
df66.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.749527   1.000000    Dhaka  192261.83
# 1         0.983359        0.828805   0.940893      Ctg  191792.06
# 2         0.927985        0.553781   0.864664  Rangpur  191050.39
# 3         0.873136        0.649738   0.812235    Dhaka  182901.99
# 4         0.859438        0.500378   0.776136  Rangpur  166187.94
